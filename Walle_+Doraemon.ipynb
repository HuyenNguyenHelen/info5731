# %% [markdown]
# <a href="https://colab.research.google.com/github/dafeng097/info5731/blob/master/Walle_%2BDoraemon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/wshuyi/demo-image-classification-fastai.git
# Out:
# Cloning into 'demo-image-classification-fastai'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 382 (delta 0), reused 0 (delta 0), pack-reused 379
# Receiving objects: 100% (382/382), 52.42 MiB | 35.55 MiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %%
from fastai.vision import *

# %%
path = Path("demo-image-classification-fastai/imgs/")

# %%
data = ImageDataBunch.from_folder(path, test='test', size=224)

# %%
data = ImageDataBunch.from_folder(path, test='test', size=224)

# %%
data.show_batch(rows=3, figuresize =(10,10))

# %%
learn = cnn_learner(data, models.resnet18, metrics=accuracy)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.torch/models/resnet18-5c106cde.pth
# 46827520it [00:00, 76230906.53it/s]

# %%
learn.fit_one_cycle(1)
# Out:
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.551718</td>
#       <td>0.166386</td>
#       <td>0.939394</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_top_losses(9,figsize = (8,8))

# %%
interp.plot_confusion_matrix()

# %%
img = learn.data.test_ds[0][0]

# %%
img
# Out:
# Image (3, 224, 224)

# %%
learn.predict(img)
# Out:
# (Category walle, tensor(1), tensor([0.0085, 0.9915]))

# %%
learn.data.test_ds
# Out:
# LabelList (6 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: EmptyLabelList
# ,,,,
# Path: demo-image-classification-fastai/imgs

# %%
learn.data.test_ds[0]
# Out:
# (Image (3, 224, 224), EmptyLabel )
